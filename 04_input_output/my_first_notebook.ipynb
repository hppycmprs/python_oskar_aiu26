# %% [markdown]
# # Inputs and outputs

# %%
print("det här fungerar")
# Out:
# det här fungerar

# %%
# This is a variable called name with the value "Oskar"
name = "Oskar"

print (name)
# Out:
# Oskar

# %%
# This is an f-string
print(f"Hello {name}")
# Out:
# Hello Oskar

# %%
name = "Anna"
age = 17
hobby = "chess"
has_rabbit = True

print(f"This is {name}")
print(f"She is {age} years old")
print(f"Her hobby is {hobby}")
print(f"She has a rabbit? {has_rabbit}")
# Out:
# This is Anna
# She is 17 years old
# Her hobby is chess
# She has a rabbit? True

# %% [markdown]
# # Inputs

# %%
name = input("Enter your name: ")
print(f"Hello {name}")
# Out:
# Hello Frank

# %%
gravity = 9.82
mass = int(input("Enter your weight in kg: "))

force = mass*gravity

print (f"Your force is {force}N")
# Out:
# Your force is 834.7N

# %%
import math

PI = math.pi

radius = 1
perimeter = 2*PI*radius
# **2 means to the power of 2
area = PI*radius**2

print(f"radius is {radius}, perimeter is {perimeter}, area is {area}")
# Out:
# radius is 1, perimeter is 6.283185307179586, area is 3.141592653589793

# %% [markdown]
# # Exercise 1 Count with Python

# %% [markdown]
# # 0. Pythagorean theorem

# %%
import math

a = 3
b = 4
c = math.sqrt(a**2+b**2)

print(c)
# Out:
# 5.0

# %%
import math

c = 7
a = 5
b = math.sqrt(24)

print(b)
# 7**2 = 5**2+b**2   49 = 25+b**2   24 = b**2
# Out:
# 4.898979485566356

# %% [markdown]
# # 1. Classification accuracy

# %%
accuracy_percentage = 300/365*100

print(accuracy_percentage)
# Out:
# 82.1917808219178

# %% [markdown]
# # 2. Classification accuracy

# %%
import math

accuracy = 987/1000*100

print(accuracy)
# Out:
# 98.7

# %% [markdown]
# # 4. Unit converter - inch to cm

# %%
import math

Print("Hej, skriv in din skärmstorlek i tum (inch)")
userinput = input
answerincm = 2.54*input

print(answerincm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 import math
#       2
# ----> 3 Print("Hej, skriv in din skärmstorlek i tum (inch)")
#       4 userinput = input
#       5 answerincm = 2.54*input
#       6
#
# NameError: name 'Print' is not defined
