# %% [markdown]
# # if statements

# %%
age = 17
age_limit = 18

if age >= age_limit:
    print("Welcome to the pub")
else:
    print("You are too young")

print("Program continues here...")
# Out:
# You are too young
# Program continues here...

# %%
# Balder
# Requirement: 140 and less than 190 cm
# At least 12 years old

height = 145
age = 14

if height < 140 or height > 190 and age < 12:
    print("You don't meet the requirements")
else:
    print("Welcome aboard")
# Out:
# Welcome aboard

# %%
# Kokchuns lösning, mer åt matematik-hållet

height = 140
age = 12

if 140 < height < 190 and age < 12:
    print("You don't meet the requirements")
else:
    print("Welcome aboard")
# Out:
# Welcome aboard

# %% [markdown]
# # if-elif-else

# %%
# Exam results
# A: 90
# B: 80
# C: 70
# D: 60
# E: 50
# F: <50
# let user input a score


print("What was your score?")
score = 60

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
elif score >= 50:
    print("E")
elif score < 50:
    print("F")
# Out:
# What was your score?
# D
